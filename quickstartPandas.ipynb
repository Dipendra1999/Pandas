# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
titanic=pd.read_csv(r'D:\Github\Pandas\usingdatasets\titanic_data.csv')

# %%
pd.set_option('display.max_columns',4)

# %%
titanic
# Out:
#      PassengerId  Survived  ...  Cabin Embarked
# 0              1         0  ...    NaN        S
# 1              2         1  ...    C85        C
# 2              3         1  ...    NaN        S
# 3              4         1  ...   C123        S
# 4              5         0  ...    NaN        S
# ..           ...       ...  ...    ...      ...
# 886          887         0  ...    NaN        S
# 887          888         1  ...    B42        S
# 888          889         0  ...    NaN        S
# 889          890         1  ...   C148        C
# 890          891         0  ...    NaN        Q
#
# [891 rows x 12 columns]

# %%
titanic.head()
#titanic.tail()
# Out:
#    PassengerId  Survived  ...  Cabin Embarked
# 0            1         0  ...    NaN        S
# 1            2         1  ...    C85        C
# 2            3         1  ...    NaN        S
# 3            4         1  ...   C123        S
# 4            5         0  ...    NaN        S
#
# [5 rows x 12 columns]

# %% [markdown]
# to check data types of columns with names

# %%
titanic.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# if i would like to store this titanic file into my system in the xlsx file then
# ***openpyxl*** module needed
# to install this: pip install openpyxl

# %%
titanic.to_excel("titanic.xlsx",sheet_name="passengers",index=False)

#to read this
#titanic = pd.read_excel("titanic.xlsx", sheet_name="passengers")

# %%
#summary
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
type(titanic["Age"])
# Out:
# pandas.core.series.Series

# %%
titanic.shape   #attribute
# Out:
# (891, 12)

# %%
age_sex= titanic[["Age","Sex"]]
age_sex.head()
# Out:
#     Age     Sex
# 0  22.0    male
# 1  38.0  female
# 2  26.0  female
# 3  35.0  female
# 4  35.0    male

# %%
type(age_sex)
# Out:
# pandas.core.frame.DataFrame

# %%
above_35=titanic[titanic["Age"]>35]
above_35.head()
# Out:
#     PassengerId  Survived  ...  Cabin Embarked
# 1             2         1  ...    C85        C
# 6             7         0  ...    E46        S
# 11           12         1  ...   C103        S
# 13           14         0  ...    NaN        S
# 15           16         1  ...    NaN        S
#
# [5 rows x 12 columns]

# %% [markdown]
# The output of the conditional expression (>, but also ==, !=, <, <=,… would work) is actually a pandas Series of boolean values (either True or False) with the same number of rows as the original DataFrame.

# %%
titanic["Age"]>35
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Age, Length: 891, dtype: bool

# %%
#cabin class 2 and 3
titanic[titanic["Pclass"].isin([2,3])]
#class23=titanic[(titanic['Pclass']==2) | (titanic['Pclass']==3)]
# Out:
#      PassengerId  Survived  ...  Cabin Embarked
# 0              1         0  ...    NaN        S
# 2              3         1  ...    NaN        S
# 4              5         0  ...    NaN        S
# 5              6         0  ...    NaN        Q
# 7              8         0  ...    NaN        S
# ..           ...       ...  ...    ...      ...
# 884          885         0  ...    NaN        S
# 885          886         0  ...    NaN        Q
# 886          887         0  ...    NaN        S
# 888          889         0  ...    NaN        S
# 890          891         0  ...    NaN        Q
#
# [675 rows x 12 columns]

# %%
age_no_na=titanic[titanic["Age"].notna()]
print(age_no_na.shape)
age_no_na.head()
# Out:
# (714, 12)
#    PassengerId  Survived  ...  Cabin Embarked
# 0            1         0  ...    NaN        S
# 1            2         1  ...    C85        C
# 2            3         1  ...    NaN        S
# 3            4         1  ...   C123        S
# 4            5         0  ...    NaN        S
#
# [5 rows x 12 columns]

# %%
titanic.loc[titanic["Age"] > 35, "Name"]    # gives the name for age >35
# Out:
# 1                                              new name
# 6                               McCarthy, Mr. Timothy J
# 11                             Bonnell, Miss. Elizabeth
# 13                          Andersson, Mr. Anders Johan
# 15                     Hewlett, Mrs. (Mary D Kingcome)
#                              ...
# 865                            Bystrom, Mrs. (Karolina)
# 871    Beckwith, Mrs. Richard Leonard (Sallie Monypeny)
# 873                         Vander Cruyssen, Mr. Victor
# 879       Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)
# 885                Rice, Mrs. William (Margaret Norton)
# Name: Name, Length: 217, dtype: object

# %%
pd.set_option('display.max_rows',10)
titanic.iloc[9:25,2:5]
# Out:
#     Pclass                                 Name     Sex
# 9        2  Nasser, Mrs. Nicholas (Adele Achem)  female
# 10       3      Sandstrom, Miss. Marguerite Rut  female
# 11       1             Bonnell, Miss. Elizabeth  female
# 12       3       Saundercock, Mr. William Henry    male
# 13       3          Andersson, Mr. Anders Johan    male
# ..     ...                                  ...     ...
# 20       2                 Fynney, Mr. Joseph J    male
# 21       2                Beesley, Mr. Lawrence    male
# 22       3          McGowan, Miss. Anna "Annie"  female
# 23       1         Sloper, Mr. William Thompson    male
# 24       3        Palsson, Miss. Torborg Danira  female
#
# [16 rows x 3 columns]

# %%
#3rd column is Name
titanic.iloc[0:4,3]="new name"

# %%
titanic["Name"].head()
# Out:
# 0                    new name
# 1                    new name
# 2                    new name
# 3                    new name
# 4    Allen, Mr. William Henry
# Name: Name, dtype: object

# %% [markdown]
# series in pandas

# %%
ages=titanic['Age']
ages.head()
# Out:
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# Name: Age, dtype: float64

# %%
type(ages)
# Out:
# pandas.core.series.Series

# %%
ages.shape
# Out:
# (891,)

# %% [markdown]
# creating plots in pandas....

# %%
air_quality=pd.read_csv(r"D:\Github\Pandas\usingdatasets\air_quality_no2.csv")
air_quality.head()
# Out:
#               datetime  station_antwerp  station_paris  station_london
# 0  2019-05-07 02:00:00              NaN            NaN            23.0
# 1  2019-05-07 03:00:00             50.5           25.0            19.0
# 2  2019-05-07 04:00:00             45.0           27.7            19.0
# 3  2019-05-07 05:00:00              NaN           50.4            16.0
# 4  2019-05-07 06:00:00              NaN           61.9             NaN

# %%
print(air_quality.shape)
air_quality.describe
# Out:
# (1035, 4)
# <bound method NDFrame.describe of                  datetime  station_antwerp  station_paris  station_london
# 0     2019-05-07 02:00:00              NaN            NaN            23.0
# 1     2019-05-07 03:00:00             50.5           25.0            19.0
# 2     2019-05-07 04:00:00             45.0           27.7            19.0
# 3     2019-05-07 05:00:00              NaN           50.4            16.0
# 4     2019-05-07 06:00:00              NaN           61.9             NaN
# ...                   ...              ...            ...             ...
# 1030  2019-06-20 22:00:00              NaN           21.4             NaN
# 1031  2019-06-20 23:00:00              NaN           24.9             NaN
# 1032  2019-06-21 00:00:00              NaN           26.5             NaN
# 1033  2019-06-21 01:00:00              NaN           21.8             NaN
# 1034  2019-06-21 02:00:00              NaN           20.0             NaN
#
# [1035 rows x 4 columns]>

# %%
air_quality.columns
# Out:
# Index(['datetime', 'station_antwerp', 'station_paris', 'station_london'], dtype='object')

# %% [markdown]
# want to check quick visual check of data

# %%
air_quality.plot()
plt.show()

# %%
air_quality["station_antwerp"].nlargest(10).plot()
plt.show()

# %%
air_quality["station_paris"].plot()
plt.show()

# %%
air_quality.plot.scatter(x='station_london',y='station_paris',c="green",s=10,alpha=0.6)
plt.show()

# %% [markdown]
# ['area',
#  'bar',
#  'barh',
#  'box',
#  'density',
#  'hexbin',
#  'hist',
#  'kde',
#  'line',
#  'pie',
#  'scatter']

# %%
air_quality.plot.box()
plt.show()

# %%
air_quality.plot.area(figsize=(12,4),subplots=True,color=['blue','black','blue'])
plt.show()

# %%
fig, axs=plt.subplots(figsize=(12,4))
air_quality.plot.area(ax=axs)
# Out:
# <Axes: >

# %%
axs.set_ylabel("NO$_2 Concentration")
fig.savefig("no2_concentration.png")
plt.show()
